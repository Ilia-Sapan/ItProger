# %%
import pandas as pd

df = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_13.csv')

# Учтите, что cols2drop в тестовой системе будет иметь другие значения.
cols2drop = ['ride_cost', 'stop_times', 'user_ride_quality']

# В ans содержится правильный ответ. Перед отправкой своего решения, сравнитесь с ним.
ans = pd.read_csv('https://stepik.org/media/attachments/lesson/681964/2_2_13_ans.csv', index_col=0)

# %%
df.head()
# Out:
#       user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 0  Q57343968C  i-6289789v     F1u  2020-03-02    1.79             35
# 1  N39662076X  F17991047v     J1A  2020-03-16    4.36             16
# 2  R39462885w  l36861534V     m1v  2020-01-20    2.20              5
# 3  q32765597m  R16189354h     v1q  2020-02-24    2.82             10
# 4  n30214850g  N-1839822D     p1h  2020-01-31    3.54             17
#
#    ride_cost  speed_avg   speed_max  stop_times     distance  refueling  \
# 0        275         87  125.463335           0  2930.798145          0
# 1        202         36   63.275887           0   472.946034          0
# 2         60         47   73.000000           0   283.626484          0
# 3        154         31   76.838507           1   100.743738          0
# 4        163         26   53.000000           1   268.451947          0
#
#    user_ride_quality  deviation_normal
# 0         -11.132653            -8.683
# 1         -28.508294           -37.196
# 2          -0.203089             3.378
# 3           0.219071            14.758
# 4          15.763025            21.179

# %%
# assign flags based on rating and speed_max
df['flag'] = 'undefined'
cond_good = (df['rating'] > 5) & (df['speed_max'] < 100)
cond_bad = (df['rating'] > 5) & (df['speed_max'] > 100)
df.loc[cond_good, 'flag'] = 'good_line'
df.loc[cond_bad, 'flag'] = 'bad_line'
df.head()
# Out:
#       user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 0  Q57343968C  i-6289789v     F1u  2020-03-02    1.79             35
# 1  N39662076X  F17991047v     J1A  2020-03-16    4.36             16
# 2  R39462885w  l36861534V     m1v  2020-01-20    2.20              5
# 3  q32765597m  R16189354h     v1q  2020-02-24    2.82             10
# 4  n30214850g  N-1839822D     p1h  2020-01-31    3.54             17
#
#    ride_cost  speed_avg   speed_max  stop_times     distance  refueling  \
# 0        275         87  125.463335           0  2930.798145          0
# 1        202         36   63.275887           0   472.946034          0
# 2         60         47   73.000000           0   283.626484          0
# 3        154         31   76.838507           1   100.743738          0
# 4        163         26   53.000000           1   268.451947          0
#
#    user_ride_quality  deviation_normal       flag
# 0         -11.132653            -8.683  undefined
# 1         -28.508294           -37.196  undefined
# 2          -0.203089             3.378  undefined
# 3           0.219071            14.758  undefined
# 4          15.763025            21.179  undefined

# %%
df["speed_check"] = "avg_less"
value = (df["speed_avg"] < df["distance"] / df["ride_duration"])
df.loc[value, "speed_check"] = "avg_more"
df.head()
# Out:
#       user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 0  Q57343968C  i-6289789v     F1u  2020-03-02    1.79             35
# 1  N39662076X  F17991047v     J1A  2020-03-16    4.36             16
# 2  R39462885w  l36861534V     m1v  2020-01-20    2.20              5
# 3  q32765597m  R16189354h     v1q  2020-02-24    2.82             10
# 4  n30214850g  N-1839822D     p1h  2020-01-31    3.54             17
#
#    ride_cost  speed_avg   speed_max  stop_times     distance  refueling  \
# 0        275         87  125.463335           0  2930.798145          0
# 1        202         36   63.275887           0   472.946034          0
# 2         60         47   73.000000           0   283.626484          0
# 3        154         31   76.838507           1   100.743738          0
# 4        163         26   53.000000           1   268.451947          0
#
#    user_ride_quality  deviation_normal       flag speed_check
# 0         -11.132653            -8.683  undefined    avg_less
# 1         -28.508294           -37.196  undefined    avg_less
# 2          -0.203089             3.378  undefined    avg_more
# 3           0.219071            14.758  undefined    avg_less
# 4          15.763025            21.179  undefined    avg_less

# %%
df.drop(columns=cols2drop, inplace=True)

# %%
df.dropna(subset=['car_id'], inplace=True)

# %%
result = df

# %%
ans.head()
# Out:
#       user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 0  Q57343968C  i-6289789v     F1u  2020-03-02    1.79             35
# 1  N39662076X  F17991047v     J1A  2020-03-16    4.36             16
# 2  R39462885w  l36861534V     m1v  2020-01-20    2.20              5
# 3  q32765597m  R16189354h     v1q  2020-02-24    2.82             10
# 4  n30214850g  N-1839822D     p1h  2020-01-31    3.54             17
#
#    speed_avg   speed_max     distance  refueling  deviation_normal       flag  \
# 0         87  125.463335  2930.798145          0            -8.683  undefined
# 1         36   63.275887   472.946034          0           -37.196  undefined
# 2         47   73.000000   283.626484          0             3.378  undefined
# 3         31   76.838507   100.743738          0            14.758  undefined
# 4         26   53.000000   268.451947          0            21.179  undefined
#
#   speed_check
# 0    avg_less
# 1    avg_less
# 2    avg_more
# 3    avg_less
# 4    avg_less

# %%
result.head()
# Out:
#       user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 0  Q57343968C  i-6289789v     F1u  2020-03-02    1.79             35
# 1  N39662076X  F17991047v     J1A  2020-03-16    4.36             16
# 2  R39462885w  l36861534V     m1v  2020-01-20    2.20              5
# 3  q32765597m  R16189354h     v1q  2020-02-24    2.82             10
# 4  n30214850g  N-1839822D     p1h  2020-01-31    3.54             17
#
#    speed_avg   speed_max     distance  refueling  deviation_normal       flag  \
# 0         87  125.463335  2930.798145          0            -8.683  undefined
# 1         36   63.275887   472.946034          0           -37.196  undefined
# 2         47   73.000000   283.626484          0             3.378  undefined
# 3         31   76.838507   100.743738          0            14.758  undefined
# 4         26   53.000000   268.451947          0            21.179  undefined
#
#   speed_check
# 0    avg_less
# 1    avg_less
# 2    avg_more
# 3    avg_less
# 4    avg_less

# %%
ans.equals(result)
# Out:
# True
